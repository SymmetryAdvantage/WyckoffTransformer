# %%
from wyckoff_transformer.evaluation.generated_dataset import load_all_from_config, GeneratedDataset
import pandas as pd

# %%
train_val_ = load_all_from_config(datasets=[("split", "train"), ("split", "val")], dataset_name="mpts_52")
train_val = pd.concat((d.data for d in train_val_.values()), axis=0, ignore_index=False)

# %%
test = GeneratedDataset.from_cache(("split", "test"), "mpts_52").data

# %%
wt = GeneratedDataset.from_cache(("WyckoffTransformer", )).data.sample(len(test), random_state=42)

# %%
from itertools import chain
from collections import Counter

# %%
def collect_tokens(fingerprint):
    return sum((Counter(dict(fs)) for fs in fingerprint[1]), Counter())

def record_to_token_counter(row):
    """
    Produces a non-augmented token counter from a row
    """
    return Counter(
        map(tuple, zip(row["elements"], row["site_symmetries"], row["sites_enumeration"])))

# %%
test_token_counts = test.apply(record_to_token_counter, axis=1).sum()

# %%
augmented_test_token_counts = test.fingerprint.apply(collect_tokens).sum()

# %%
train_val_token_counts = train_val.fingerprint.apply(collect_tokens).sum()

# %%
wt_token_counts = wt.apply(record_to_token_counter, axis=1).sum()

# %%
len(test)
# Out:
# 8096

# %%
len(test_token_counts.keys() - train_val_token_counts.keys())
# Out:
# 313

# %% [markdown]
# 1. There are no precise details on how many tokens were formed from the MP-20 dataset after tokenization. It would be interesting to discuss this number and other statistics about the tokens, e.g., which tokens are present more often (for some of the high symmetry space groups) and how the distribution of tokens affects training.

# %%
mp_20_token_counts = augmented_test_token_counts + train_val_token_counts

# %%
len(mp_20_token_counts)
# Out:
# 10810

# %%
mp_20_token_freq_pd = pd.Series(mp_20_token_counts).sort_values(ascending=False)
mp_20_token_freq_pd /= mp_20_token_freq_pd.sum()
# Out:
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.12/lib/python3.12/site-packages/pymatgen/core/periodic_table.py:255: UserWarning: No Pauling electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   if not hasattr(other, "X") or not hasattr(other, "symbol"):
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.12/lib/python3.12/site-packages/pymatgen/core/periodic_table.py:258: UserWarning: No Pauling electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   x2 = float("inf") if other.X != other.X else other.X
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.12/lib/python3.12/site-packages/pymatgen/core/periodic_table.py:255: UserWarning: No Pauling electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   if not hasattr(other, "X") or not hasattr(other, "symbol"):
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.12/lib/python3.12/site-packages/pymatgen/core/periodic_table.py:258: UserWarning: No Pauling electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   x2 = float("inf") if other.X != other.X else other.X
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.12/lib/python3.12/site-packages/pymatgen/core/periodic_table.py:255: UserWarning: No Pauling electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   if not hasattr(other, "X") or not hasattr(other, "symbol"):
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.12/lib/python3.12/site-packages/pymatgen/core/periodic_table.py:258: UserWarning: No Pauling electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   x2 = float("inf") if other.X != other.X else other.X
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.12/lib/python3.12/site-packages/pymatgen/core/periodic_table.py:257: UserWarning: No Pauling electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   x1 = float("inf") if self.X != self.X else self.X
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.12/lib/python3.12/site-packages/pymatgen/core/periodic_table.py:257: UserWarning: No Pauling electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   x1 = float("inf") if self.X != self.X else self.X
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.12/lib/python3.12/site-packages/pymatgen/core/periodic_table.py:257: UserWarning: No Pauling electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   x1 = float("inf") if self.X != self.X else self.X

# %%
import matplotlib
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
mp_20_token_freq_pd.hist(bins=500, ax=ax)
threshold = 0.01
ax.set_xlim(0, threshold)
ax.set_xlabel("Token frequency in MPTS-52")
ax.set_ylabel("Number of tokens")
ax.set_yscale("log")
ax.set_title(f"Token frequency distribution in MPTS-52 for {(mp_20_token_freq_pd < 0.01).sum()} tokens with frequency < {threshold}")
fig.tight_layout()
fig.savefig("mpts_52_token_hist.pdf")

# %%
font = {'size': 7}
matplotlib.rc('font', **font)
fig, ax = plt.subplots(figsize=(10, 0.5))
start = 0
top_count = 30
cmap = matplotlib.colormaps['tab10']
for i, (token, frequency) in enumerate(mp_20_token_freq_pd.iloc[:top_count].items()):
    ax.barh(0, frequency, left=start, color=cmap(i % cmap.N), label=f"{token[0]}, {token[1]}, {token[2]}")
    start += frequency
ax.set_yticks([])
ax.set_xlabel(f"Token frequency in MPTS-52 for top {top_count} tokens")
legend = ax.legend(ncol=7, bbox_to_anchor=(0.5, 2.2), loc='center')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
fig.savefig("mpts_52_token_top.pdf", bbox_extra_artists=(legend,), bbox_inches='tight')

# %% [markdown]
# 2. It is also important to add how many new tokens the method generates or if it just predicts the fixed set of tokens in different combinations (and these combinations result in more template novelty than just sampling existing templates from training data). For instance, naively thinking about it, how will your model generate tokens that are not present in its dictionary?

# %%
print(len(wt_token_counts.keys() - train_val_token_counts.keys()), len(test_token_counts.keys() - train_val_token_counts.keys()))
# Out:
# 575 313

# %%
len(wt_token_counts.keys() - train_val_token_counts.keys())/len(wt)*28
# Out:
# 1.9886363636363638

# %% [markdown]
# 3. Another thing is that the token space is relatively smaller, so how can it be argued that these tokens cover all possible values a token could take in real material? Since we do not expect to see new tokens during generation, it should be added as a limitation of the method.

# %%
(wt_token_counts - train_val_token_counts).most_common(10)
# Out:
# [((Element Mo, '3m.', 0), 33),
#  ((Element F, 'm', 1), 33),
#  ((Element Mn, 'm', 0), 32),
#  ((Element Mo, '3m.', 2), 31),
#  ((Element W, '3m.', 0), 24),
#  ((Element W, '3m.', 2), 23),
#  ((Element Pm, 'm-3m', 0), 22),
#  ((Element Pm, 'm-3m', 1), 21),
#  ((Element Rh, '-43m', 0), 20),
#  ((Element Te, '3m.', 2), 18)]

# %%
len(wt)-wt.fingerprint.isin(train_val.fingerprint).sum()
# Out:
# 7699

# %%
75*81*8
# Out:
# 48600

# %%
import gzip
import pickle
with gzip.open("../cache/wychoffs_enumerated_by_ss.pkl.gz", "rb") as f:
    a, letter_from_ss_enum, ss_from_letter = pickle.load(f)

# %%
all_ss = frozenset(chain(*((s.values() for s in ss_from_letter.values()))))

# %%
missing_ss = all_ss - frozenset(mp_20_token_freq_pd.index.get_level_values(1).unique())

# %%
missing_ss
# Out:
# frozenset({'42.2', '6..', '622'})
